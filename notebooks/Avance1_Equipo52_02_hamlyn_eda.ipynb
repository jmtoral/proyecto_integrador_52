# %% [markdown]
# # <center> <font color="#0036a3">Maestría en Inteligencia Artificial Aplicada (MNA)</font> </center>
#
# <center>
#
# [![Institución](https://img.shields.io/badge/INSTITUCIÓN-TECNOLÓGICO_DE_MONTERREY-0036a3?style=for-the-badge)](https://tec.mx)
# [![Programa](https://img.shields.io/badge/PROGRAMA-MNA-0036a3?style=for-the-badge)](https://tec.mx)
# [![Materia](https://img.shields.io/badge/MATERIA-PROYECTO_INTEGRADOR-E0A800?style=for-the-badge&logoColor=white)](https://tec.mx)
#
# </center>
#
# <center>
#
# [![Python](https://img.shields.io/badge/Python-3776AB?style=flat-square&logo=python&logoColor=white)](https://www.python.org/)
# [![Jupyter](https://img.shields.io/badge/Jupyter-F37626?style=flat-square&logo=jupyter&logoColor=white)](https://jupyter.org/)
# [![NumPy](https://img.shields.io/badge/NumPy-013243?style=flat-square&logo=numpy&logoColor=white)](https://numpy.org/)
# [![OpenCV](https://img.shields.io/badge/OpenCV-5C3EE8?style=flat-square&logo=opencv&logoColor=white)](https://opencv.org/)
# [![GitHub](https://img.shields.io/badge/Repo-GitHub-181717?style=flat-square&logo=github&logoColor=white)](https://github.com/jmtoral/proyecto_integrador_52)
#
# </center>
#
# ---
#
# ## **<font color="#0036a3">Semana 3: Avance 1 — Análisis Exploratorio de Datos (EDA)</font>**
#
# ### **<font color="#E0A800">Proyecto Integrador — TC5035.10</font>**
# **Materia:** Proyecto Integrador — TC5035.10
#
# > **Título:** La luz que opaca: Detección y supresión de reflejos especulares en imágenes endoscópicas.
#
# ---
#
# ### **Equipo Docente**
# * **Dra. Grettel Barceló Alonso** | Profesora Titular
# * **Dr. Luis Eduardo Falcón Morales** | Profesor Titular
# * **Mtra. Verónica Sandra Guzmán de Valle** | Profesora Asistente
#
# **Patrocinador:** Dr. Gerardo Camacho
#
# ---
#
# ## **<center> <font color="#0036a3">Equipo 52</font> </center>**
#
# <table style="width:100%; border:none; border-collapse:collapse;">
#   <tr>
#     <td align="center" style="border:none; width:33%; padding:10px;">
#       <img src="https://raw.githubusercontent.com/jmtoral/proyecto_integrador_52/main/reports/elda.jpg" width="160px" height="160px" style="border-radius:50%; object-fit:cover;">
#       <br>
#       <h4>Elda Cristina Morales Sánchez de la Barquera</h4>
#       <code>A00449074</code><br>
#       <small>MNA Student</small>
#     </td>
#     <td align="center" style="border:none; width:33%; padding:10px;">
#       <img src="https://raw.githubusercontent.com/jmtoral/proyecto_integrador_52/main/reports/mpgc.jpg" width="160px" height="160px" style="border-radius:50%; object-fit:cover;">
#       <br>
#       <h4>María Paula Gutiérrez Cervantes</h4>
#       <code>A01747706</code><br>
#       <small>MNA Student</small>
#     </td>
#     <td align="center" style="border:none; width:33%; padding:10px;">
#       <img src="https://raw.githubusercontent.com/jmtoral/proyecto_integrador_52/main/reports/jmtc.jpg" width="160px" height="160px" style="border-radius:50%; object-fit:cover;">
#       <br>
#       <h4>José Manuel Toral Cruz</h4>
#       <code>A01122243</code><br>
#       <small>MNA Student</small>
#     </td>
#   </tr>
# </table>
#
# ---
#
# ### **<font color="#E0A800">Información de Entrega</font>**
# * **Actividad:** Avance 1. Análisis exploratorio de datos.
# * **Fecha Límite:** 11 de mayo de 2026
# * **Framework de Calidad:** CRISP-ML(Q)
# * **Objetivos Clave:**
#     * **EDA Hamlyn:** Exploración y caracterización del dataset Hamlyn Centre Endoscopic Video.
#     * **Métricas:** Estructura de secuencias, resolución, cobertura de profundidad, calidad de iluminación.

# %% [markdown]
# ## 1. Configuración inicial
#
# Estructura esperada:
#
# ```text
# proyecto_integrador_52/
# ├── data/
# │   └── hamlyn/
# │       ├── raw_zip/
# │       ├── intrinsics/
# │       └── extracted/
# │           ├── rectified01/
# │           ├── rectified04/
# │           ├── rectified05/
# │           ├── rectified06/
# │           └── rectified08/
# ├── notebooks/
# └── outputs/
#     └── hamlyn/
# ```

# %%
# Si falta alguna librería, ejecutar una sola vez:
# !pip install pandas numpy matplotlib pillow imageio tqdm

from pathlib import Path
import os
import re
import warnings
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import imageio.v3 as iio
from tqdm.auto import tqdm

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 140)

print("Librerías cargadas correctamente.")
# Out:
# Librerías cargadas correctamente.

# %%
def find_project_root(start=None):
    start = Path(start or Path.cwd()).resolve()
    candidates = [start] + list(start.parents)
    for candidate in candidates:
        if (candidate / "data" / "hamlyn").exists():
            return candidate
    return start

PROJECT_ROOT = find_project_root()
HAMLYN_DIR = PROJECT_ROOT / "data" / "hamlyn"
RAW_ZIP_DIR = HAMLYN_DIR / "raw_zip"
INTRINSICS_DIR = HAMLYN_DIR / "intrinsics"
EXTRACTED_DIR = HAMLYN_DIR / "extracted"
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "hamlyn"

(OUTPUT_DIR / "tables").mkdir(parents=True, exist_ok=True)
(OUTPUT_DIR / "figures").mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("HAMLYN_DIR:", HAMLYN_DIR)
print("EXTRACTED_DIR:", EXTRACTED_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# PROJECT_ROOT: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52
# HAMLYN_DIR: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn
# EXTRACTED_DIR: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted
# OUTPUT_DIR: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn

# %% [markdown]
# ## 2. Verificación de descarga y descompresión
#
# Se validan los ZIP, las carpetas extraídas y los archivos de calibración.

# %%
expected_sequences = ["rectified01", "rectified04", "rectified05", "rectified06", "rectified08"]

zip_inventory = []
for seq in expected_sequences:
    zip_path = RAW_ZIP_DIR / f"{seq}.zip"
    extracted_path = EXTRACTED_DIR / seq
    intrinsics_path = INTRINSICS_DIR / f"intrinsics_{seq}.txt"
    zip_inventory.append({
        "sequence": seq,
        "zip_exists": zip_path.exists(),
        "zip_size_mb": round(zip_path.stat().st_size / (1024**2), 2) if zip_path.exists() else np.nan,
        "extracted_exists": extracted_path.exists(),
        "intrinsics_exists": intrinsics_path.exists(),
        "intrinsics_size_kb": round(intrinsics_path.stat().st_size / 1024, 2) if intrinsics_path.exists() else np.nan
    })

zip_df = pd.DataFrame(zip_inventory)
display(zip_df)

zip_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_download_inventory.csv", index=False)
# Out:
#       sequence  zip_exists  zip_size_mb  extracted_exists  intrinsics_exists  \
# 0  rectified01        True       188.48              True               True
# 1  rectified04        True       125.34              True               True
# 2  rectified05        True        80.86              True               True
# 3  rectified06        True       245.20              True               True
# 4  rectified08        True      2269.24              True               True
#
#    intrinsics_size_kb
# 0                0.07
# 1                0.07
# 2                0.07
# 3                0.07
# 4                0.07

# %% [markdown]
# ## 3. Inventario general de archivos
#
# Esta sección cuantifica la volumetría del dataset: número de archivos por secuencia, extensión, tamaño total y organización general.

# %%
def list_files(base_dir):
    records = []
    base_dir = Path(base_dir)
    if not base_dir.exists():
        print(f"No existe la carpeta: {base_dir}")
        return pd.DataFrame()

    for path in base_dir.rglob("*"):
        if path.is_file():
            rel = path.relative_to(base_dir)
            parts = rel.parts
            seq = next((p for p in parts if p.startswith("rectified")), "unknown")
            records.append({
                "sequence": seq,
                "relative_path": str(rel),
                "filename": path.name,
                "extension": path.suffix.lower(),
                "size_mb": path.stat().st_size / (1024**2),
                "absolute_path": str(path)
            })
    return pd.DataFrame(records)

files_df = list_files(EXTRACTED_DIR)
print("Total de archivos descomprimidos:", len(files_df))
display(files_df.head())

if not files_df.empty:
    summary_ext = (
        files_df.groupby(["sequence", "extension"])
        .agg(n_files=("filename", "count"), total_size_mb=("size_mb", "sum"))
        .reset_index()
        .sort_values(["sequence", "extension"])
    )
    summary_ext["total_size_mb"] = summary_ext["total_size_mb"].round(2)
else:
    summary_ext = pd.DataFrame()

display(summary_ext)

files_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_all_files_inventory.csv", index=False)
summary_ext.to_csv(OUTPUT_DIR / "tables" / "hamlyn_filetype_summary.csv", index=False)
# Out:
# Total de archivos descomprimidos: 76640
#       sequence                                   relative_path  \
# 0  rectified04  rectified04/rectified04/image01/0000000544.jpg
# 1  rectified04  rectified04/rectified04/image01/0000000222.jpg
# 2  rectified04  rectified04/rectified04/image01/0000001128.jpg
# 3  rectified04  rectified04/rectified04/image01/0000000236.jpg
# 4  rectified04  rectified04/rectified04/image01/0000000550.jpg
#
#          filename extension   size_mb  \
# 0  0000000544.jpg      .jpg  0.027141
# 1  0000000222.jpg      .jpg  0.026549
# 2  0000001128.jpg      .jpg  0.030452
# 3  0000000236.jpg      .jpg  0.027350
# 4  0000000550.jpg      .jpg  0.026946
#
#                                                                                                                                  absolute_path
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
#       sequence extension  n_files  total_size_mb
# 0  rectified01      .jpg     2116          71.60
# 1  rectified01      .png     2116         116.14
# 2  rectified04      .jpg     3146          84.76
# 3  rectified04      .png     3146          39.35
# 4  rectified05      .jpg     1798          53.63
# 5  rectified05      .png     1798          26.55
# 6  rectified06      .jpg     2474         103.34
# 7  rectified06      .png     2474         140.92
# 8  rectified08      .jpg    28786        1216.90
# 9  rectified08      .png    28786        1044.89

# %% [markdown]
# ## 4. Muestra de estructura interna
#
# Se imprime un árbol parcial por secuencia para documentar la organización física de carpetas.

# %%
def print_tree(path, max_depth=3, max_items_per_level=15):
    path = Path(path)
    if not path.exists():
        print(f"No existe: {path}")
        return

    def _print(current, prefix="", depth=0):
        if depth > max_depth:
            return
        items = sorted(list(current.iterdir()), key=lambda p: (p.is_file(), p.name.lower()))
        shown = items[:max_items_per_level]
        hidden = max(0, len(items) - max_items_per_level)
        for item in shown:
            marker = "📁" if item.is_dir() else "📄"
            print(f"{prefix}{marker} {item.name}")
            if item.is_dir():
                _print(item, prefix + "   ", depth + 1)
        if hidden:
            print(f"{prefix}... {hidden} elementos más")

    print(f"Árbol de: {path}")
    _print(path)

for seq in expected_sequences:
    print("\n" + "="*80)
    print_tree(EXTRACTED_DIR / seq)
# Out:
# ================================================================================
# Árbol de: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01
# 📁 rectified01
#    📁 depth01
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1043 elementos más
#    📁 depth02
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1043 elementos más
#    📁 image01
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1043 elementos más
#    📁 image02
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1043 elementos más
#
# ================================================================================
# Árbol de: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04
# 📁 rectified04
#    📁 depth01
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1558 elementos más
#    📁 depth02
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1558 elementos más
#    📁 image01
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1558 elementos más
#    📁 image02
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1558 elementos más
#
# ================================================================================
# Árbol de: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified05
# 📁 rectified05
#    📁 depth01
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 884 elementos más
#    📁 depth02
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 884 elementos más
#    📁 image01
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 884 elementos más
#    📁 image02
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 884 elementos más
#
# ================================================================================
# Árbol de: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified06
# 📁 rectified06
#    📁 depth01
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1222 elementos más
#    📁 depth02
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 1222 elementos más
#    📁 image01
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1222 elementos más
#    📁 image02
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 1222 elementos más
#
# ================================================================================
# Árbol de: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified08
# 📁 rectified08
#    📁 depth01
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 14378 elementos más
#    📁 depth02
#       📄 0000000000.png
#       📄 0000000001.png
#       📄 0000000002.png
#       📄 0000000003.png
#       📄 0000000004.png
#       📄 0000000005.png
#       📄 0000000006.png
#       📄 0000000007.png
#       📄 0000000008.png
#       📄 0000000009.png
#       📄 0000000010.png
#       📄 0000000011.png
#       📄 0000000012.png
#       📄 0000000013.png
#       📄 0000000014.png
#       ... 14378 elementos más
#    📁 image01
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 14378 elementos más
#    📁 image02
#       📄 0000000000.jpg
#       📄 0000000001.jpg
#       📄 0000000002.jpg
#       📄 0000000003.jpg
#       📄 0000000004.jpg
#       📄 0000000005.jpg
#       📄 0000000006.jpg
#       📄 0000000007.jpg
#       📄 0000000008.jpg
#       📄 0000000009.jpg
#       📄 0000000010.jpg
#       📄 0000000011.jpg
#       📄 0000000012.jpg
#       📄 0000000013.jpg
#       📄 0000000014.jpg
#       ... 14378 elementos más

# %% [markdown]
# ## 5. Clasificación heurística de archivos
#
# Se clasifican los archivos por nombre, ruta y extensión. Como los datasets pueden tener estructuras heterogéneas, esta clasificación es inicial y se confirma leyendo metadatos.

# %%
def classify_file(row):
    path = str(row.get("relative_path", "")).lower()
    ext = row.get("extension", "").lower()

    if ext not in [".jpg", ".jpeg", ".png", ".tif", ".tiff", ".bmp"]:
        return "other"

    depth_terms = ["depth", "gt", "groundtruth", "ground_truth", "disp", "disparity"]
    if any(term in path for term in depth_terms):
        return "depth_map"

    left_terms = ["left", "/l/", "_l_", "image_02", "cam0", "left_image"]
    right_terms = ["right", "/r/", "_r_", "image_03", "cam1", "right_image"]

    if any(term in path for term in left_terms):
        return "left_image"
    if any(term in path for term in right_terms):
        return "right_image"

    return "other_image"

if not files_df.empty:
    files_df["file_role_heuristic"] = files_df.apply(classify_file, axis=1)
    role_summary = (
        files_df.groupby(["sequence", "file_role_heuristic"])
        .agg(n_files=("filename", "count"), total_size_mb=("size_mb", "sum"))
        .reset_index()
        .sort_values(["sequence", "file_role_heuristic"])
    )
    role_summary["total_size_mb"] = role_summary["total_size_mb"].round(2)
else:
    role_summary = pd.DataFrame()

display(role_summary)
role_summary.to_csv(OUTPUT_DIR / "tables" / "hamlyn_role_summary_heuristic.csv", index=False)
# Out:
#       sequence file_role_heuristic  n_files  total_size_mb
# 0  rectified01           depth_map     2116         116.14
# 1  rectified01         other_image     2116          71.60
# 2  rectified04           depth_map     3146          39.35
# 3  rectified04         other_image     3146          84.76
# 4  rectified05           depth_map     1798          26.55
# 5  rectified05         other_image     1798          53.63
# 6  rectified06           depth_map     2474         140.92
# 7  rectified06         other_image     2474         103.34
# 8  rectified08           depth_map    28786        1044.89
# 9  rectified08         other_image    28786        1216.90

# %% [markdown]
# ## 6. Lectura de metadatos de imágenes
#
# Se inspecciona resolución, modo de color y formato sin cargar completamente todos los archivos a memoria.

# %%
image_exts = [".jpg", ".jpeg", ".png", ".tif", ".tiff", ".bmp"]
image_files_df = files_df[files_df["extension"].isin(image_exts)].copy() if not files_df.empty else pd.DataFrame()

def inspect_image_metadata(path):
    try:
        with Image.open(path) as img:
            return {"width": img.width, "height": img.height, "mode": img.mode, "format": img.format}
    except Exception:
        return {"width": np.nan, "height": np.nan, "mode": "ERROR", "format": "ERROR"}

metadata_records = []
for _, row in tqdm(image_files_df.iterrows(), total=len(image_files_df), desc="Inspeccionando metadatos"):
    meta = inspect_image_metadata(row["absolute_path"])
    metadata_records.append({**row.to_dict(), **meta})

image_meta_df = pd.DataFrame(metadata_records)
print("Total de imágenes inspeccionadas:", len(image_meta_df))
display(image_meta_df.head())

if not image_meta_df.empty:
    resolution_summary = (
        image_meta_df.groupby(["sequence", "width", "height", "mode", "format", "file_role_heuristic"])
        .agg(n_files=("filename", "count"))
        .reset_index()
        .sort_values(["sequence", "n_files"], ascending=[True, False])
    )
else:
    resolution_summary = pd.DataFrame()

display(resolution_summary)

image_meta_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_image_metadata.csv", index=False)
resolution_summary.to_csv(OUTPUT_DIR / "tables" / "hamlyn_resolution_summary.csv", index=False)
# Out:
# Inspeccionando metadatos:   0%|          | 0/76640 [00:00<?, ?it/s]
# Total de imágenes inspeccionadas: 76640
#       sequence                                   relative_path  \
# 0  rectified04  rectified04/rectified04/image01/0000000544.jpg
# 1  rectified04  rectified04/rectified04/image01/0000000222.jpg
# 2  rectified04  rectified04/rectified04/image01/0000001128.jpg
# 3  rectified04  rectified04/rectified04/image01/0000000236.jpg
# 4  rectified04  rectified04/rectified04/image01/0000000550.jpg
#
#          filename extension   size_mb  \
# 0  0000000544.jpg      .jpg  0.027141
# 1  0000000222.jpg      .jpg  0.026549
# 2  0000001128.jpg      .jpg  0.030452
# 3  0000000236.jpg      .jpg  0.027350
# 4  0000000550.jpg      .jpg  0.026946
#
#                                                                                                                                  absolute_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
#
#   file_role_heuristic  width  height mode format
# 0         other_image    360     288  RGB   JPEG
# 1         other_image    360     288  RGB   JPEG
# 2         other_image    360     288  RGB   JPEG
# 3         other_image    360     288  RGB   JPEG
# 4         other_image    360     288  RGB   JPEG
#       sequence  width  height  mode format file_role_heuristic  n_files
# 0  rectified01    640     480  I;16    PNG           depth_map     2116
# 1  rectified01    640     480   RGB   JPEG         other_image     2116
# 2  rectified04    360     288  I;16    PNG           depth_map     3146
# 3  rectified04    360     288   RGB   JPEG         other_image     3146
# 4  rectified05    360     288  I;16    PNG           depth_map     1798
# 5  rectified05    360     288   RGB   JPEG         other_image     1798
# 6  rectified06    640     480  I;16    PNG           depth_map     2474
# 7  rectified06    640     480   RGB   JPEG         other_image     2474
# 8  rectified08    640     480  I;16    PNG           depth_map    28786
# 9  rectified08    640     480   RGB   JPEG         other_image    28786

# %% [markdown]
# ## 7. Identificación de mapas de profundidad
#
# En HAMLYN rectificado, los mapas de profundidad suelen almacenarse como PNG de 16 bits con valores en milímetros. Esta sección identifica posibles mapas de profundidad por tipo de dato y rango de valores.

# %%
def read_image_array(path):
    try:
        return iio.imread(path)
    except Exception:
        try:
            return np.array(Image.open(path))
        except Exception:
            return None

def infer_array_type(arr):
    if arr is None:
        return "error"
    if arr.ndim == 3 and arr.shape[-1] in [3, 4]:
        return "rgb_or_rgba"
    if arr.ndim == 2 and arr.dtype in [np.uint16, np.int16, np.uint32, np.float32, np.float64]:
        return "possible_depth"
    if arr.ndim == 2 and arr.dtype == np.uint8:
        return "grayscale_uint8"
    return "other"

candidate_depth_df = image_meta_df[image_meta_df["extension"].isin([".png", ".tif", ".tiff"])].copy()

depth_probe_records = []
for _, row in tqdm(candidate_depth_df.iterrows(), total=len(candidate_depth_df), desc="Revisando profundidad"):
    arr = read_image_array(row["absolute_path"])
    if arr is None:
        stats = {"array_type": "error", "dtype": "error", "ndim": np.nan, "shape": None,
                 "min": np.nan, "max": np.nan, "mean": np.nan}
    else:
        stats = {
            "array_type": infer_array_type(arr),
            "dtype": str(arr.dtype),
            "ndim": arr.ndim,
            "shape": str(arr.shape),
            "min": float(np.nanmin(arr)),
            "max": float(np.nanmax(arr)),
            "mean": float(np.nanmean(arr))
        }
    depth_probe_records.append({**row.to_dict(), **stats})

depth_probe_df = pd.DataFrame(depth_probe_records)

if not depth_probe_df.empty:
    depth_probe_df["is_depth_candidate"] = (
        (depth_probe_df["array_type"] == "possible_depth") |
        (depth_probe_df["file_role_heuristic"] == "depth_map") |
        ((depth_probe_df["extension"] == ".png") & (depth_probe_df["max"] > 255))
    )
    depth_candidates = depth_probe_df[depth_probe_df["is_depth_candidate"]].copy()
else:
    depth_candidates = pd.DataFrame()

print("Posibles mapas de profundidad detectados:", len(depth_candidates))
display(depth_candidates[["sequence", "relative_path", "dtype", "shape", "min", "max", "mean"]].head(20))

depth_probe_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_depth_probe.csv", index=False)
depth_candidates.to_csv(OUTPUT_DIR / "tables" / "hamlyn_depth_candidates.csv", index=False)
# Out:
# Revisando profundidad:   0%|          | 0/38320 [00:00<?, ?it/s]
# Posibles mapas de profundidad detectados: 38320
#        sequence                                   relative_path   dtype  \
# 0   rectified04  rectified04/rectified04/depth01/0000000949.png  uint16
# 1   rectified04  rectified04/rectified04/depth01/0000000791.png  uint16
# 2   rectified04  rectified04/rectified04/depth01/0000000785.png  uint16
# 3   rectified04  rectified04/rectified04/depth01/0000000975.png  uint16
# 4   rectified04  rectified04/rectified04/depth01/0000000961.png  uint16
# 5   rectified04  rectified04/rectified04/depth01/0000000752.png  uint16
# 6   rectified04  rectified04/rectified04/depth01/0000000034.png  uint16
# 7   rectified04  rectified04/rectified04/depth01/0000000020.png  uint16
# 8   rectified04  rectified04/rectified04/depth01/0000000746.png  uint16
# 9   rectified04  rectified04/rectified04/depth01/0000001458.png  uint16
# 10  rectified04  rectified04/rectified04/depth01/0000001470.png  uint16
# 11  rectified04  rectified04/rectified04/depth01/0000001316.png  uint16
# 12  rectified04  rectified04/rectified04/depth01/0000000008.png  uint16
# 13  rectified04  rectified04/rectified04/depth01/0000001302.png  uint16
# 14  rectified04  rectified04/rectified04/depth01/0000001464.png  uint16
# 15  rectified04  rectified04/rectified04/depth01/0000000593.png  uint16
# 16  rectified04  rectified04/rectified04/depth01/0000000587.png  uint16
# 17  rectified04  rectified04/rectified04/depth01/0000000236.png  uint16
# 18  rectified04  rectified04/rectified04/depth01/0000001128.png  uint16
# 19  rectified04  rectified04/rectified04/depth01/0000000550.png  uint16
#
#          shape  min   max       mean
# 0   (288, 360)  0.0  64.0  29.248331
# 1   (288, 360)  0.0  51.0  18.726379
# 2   (288, 360)  0.0  54.0  24.464911
# 3   (288, 360)  0.0  60.0  21.943403
# 4   (288, 360)  0.0  60.0  24.267689
# 5   (288, 360)  0.0  52.0  23.624267
# 6   (288, 360)  0.0  53.0  23.564304
# 7   (288, 360)  0.0  53.0  23.110523
# 8   (288, 360)  0.0  52.0  21.770370
# 9   (288, 360)  0.0  59.0  28.049035
# 10  (288, 360)  0.0  60.0  27.488648
# 11  (288, 360)  0.0  57.0  23.448736
# 12  (288, 360)  0.0  52.0  24.121962
# 13  (288, 360)  0.0  57.0  23.058864
# 14  (288, 360)  0.0  59.0  28.224749
# 15  (288, 360)  0.0  52.0  24.812587
# 16  (288, 360)  0.0  52.0  23.754851
# 17  (288, 360)  0.0  51.0  23.609799
# 18  (288, 360)  0.0  60.0  27.226485
# 19  (288, 360)  0.0  51.0  23.279967

# %% [markdown]
# ## 8. Lectura de calibración intrínseca
#
# Los archivos `intrinsics_rectifiedXX.txt` contienen parámetros de cámara necesarios para interpretar geométricamente las imágenes.

# %%
intrinsics_records = []

for seq in expected_sequences:
    intr_path = INTRINSICS_DIR / f"intrinsics_{seq}.txt"
    if intr_path.exists():
        text = intr_path.read_text(errors="ignore")
        numbers = re.findall(r"[-+]?\d*\.\d+|[-+]?\d+", text)
        numbers = [float(x) for x in numbers]
        intrinsics_records.append({
            "sequence": seq,
            "path": str(intr_path),
            "raw_text": text.strip(),
            "numbers_detected": numbers,
            "n_numbers": len(numbers)
        })
    else:
        intrinsics_records.append({
            "sequence": seq,
            "path": str(intr_path),
            "raw_text": None,
            "numbers_detected": [],
            "n_numbers": 0
        })

intrinsics_df = pd.DataFrame(intrinsics_records)
display(intrinsics_df[["sequence", "path", "n_numbers", "raw_text"]])

intrinsics_df[["sequence", "path", "n_numbers", "raw_text"]].to_csv(
    OUTPUT_DIR / "tables" / "hamlyn_intrinsics_summary.csv", index=False
)
# Out:
#       sequence  \
# 0  rectified01
# 1  rectified04
# 2  rectified05
# 3  rectified06
# 4  rectified08
#
#                                                                                                                                         path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/intrinsics/intrinsics_rectified01.txt
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/intrinsics/intrinsics_rectified04.txt
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/intrinsics/intrinsics_rectified05.txt
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/intrinsics/intrinsics_rectified06.txt
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/intrinsics/intrinsics_rectified08.txt
#
#    n_numbers  \
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#
#                                                                         raw_text
# 0  383.1901395 0 155.9659519195557 0\n0 383.1901395 124.3335933685303 0\n0 0 1 0
# 1      579.05693 0 139.9316005706787 0\n0 579.05693 159.0189905166626 0\n0 0 1 0
# 2      579.05693 0 139.9316005706787 0\n0 579.05693 159.0189905166626 0\n0 0 1 0
# 3  765.8236885 0 276.4727783203125 0\n0 765.8236885 253.6752815246582 0\n0 0 1 0
# 4  765.8236885 0 276.4727783203125 0\n0 765.8236885 253.6752815246582 0\n0 0 1 0

# %%
# Limpieza de rutas absolutas en la tabla de intrínsecos.
# Convierte rutas locales de la computadora en rutas relativas al proyecto.

intrinsics_clean_df = intrinsics_df.copy()

if "path" in intrinsics_clean_df.columns:
    intrinsics_clean_df["path"] = intrinsics_clean_df["path"].apply(
        lambda p: str(Path(p).resolve().relative_to(PROJECT_ROOT)) if p is not None and Path(p).exists() else p
    )

intrinsics_clean_df[["sequence", "path", "n_numbers", "raw_text"]].to_csv(
    OUTPUT_DIR / "tables" / "hamlyn_intrinsics_summary.csv",
    index=False
)

display(intrinsics_clean_df[["sequence", "path", "n_numbers", "raw_text"]])

print("Archivo de intrínsecos actualizado con rutas relativas:")
print(OUTPUT_DIR / "tables" / "hamlyn_intrinsics_summary.csv")
# Out:
#       sequence                                               path  n_numbers  \
# 0  rectified01  data/hamlyn/intrinsics/intrinsics_rectified01.txt         12
# 1  rectified04  data/hamlyn/intrinsics/intrinsics_rectified04.txt         12
# 2  rectified05  data/hamlyn/intrinsics/intrinsics_rectified05.txt         12
# 3  rectified06  data/hamlyn/intrinsics/intrinsics_rectified06.txt         12
# 4  rectified08  data/hamlyn/intrinsics/intrinsics_rectified08.txt         12
#
#                                                                         raw_text
# 0  383.1901395 0 155.9659519195557 0\n0 383.1901395 124.3335933685303 0\n0 0 1 0
# 1      579.05693 0 139.9316005706787 0\n0 579.05693 159.0189905166626 0\n0 0 1 0
# 2      579.05693 0 139.9316005706787 0\n0 579.05693 159.0189905166626 0\n0 0 1 0
# 3  765.8236885 0 276.4727783203125 0\n0 765.8236885 253.6752815246582 0\n0 0 1 0
# 4  765.8236885 0 276.4727783203125 0\n0 765.8236885 253.6752815246582 0\n0 0 1 0
# Archivo de intrínsecos actualizado con rutas relativas:
# /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn/tables/hamlyn_intrinsics_summary.csv

# %% [markdown]
# ## 9. Estadísticas de profundidad
#
# Criterio inicial de validez:
#
# ```text
# 1 mm <= profundidad <= 300 mm
# ```

# %%
MIN_VALID_DEPTH_MM = 1
MAX_VALID_DEPTH_MM = 300

# Para analizar toda la base: DEPTH_STRIDE = 1.
# Para pruebas rápidas: 10, 20, 50, etc.
DEPTH_STRIDE = 1

depth_files_to_process = depth_candidates.sort_values(["sequence", "relative_path"]).iloc[::DEPTH_STRIDE].copy()
print("Mapas de profundidad a procesar:", len(depth_files_to_process))
# Out:
# Mapas de profundidad a procesar: 38320

# %%
def compute_depth_stats(path, min_valid=1, max_valid=300):
    arr = read_image_array(path)
    if arr is None:
        return {"error": True}

    if arr.ndim == 3:
        arr = arr[..., 0]
    arr = arr.astype(np.float32)

    total = arr.size
    valid_mask = np.isfinite(arr) & (arr >= min_valid) & (arr <= max_valid)
    valid = arr[valid_mask]

    result = {
        "error": False,
        "height": arr.shape[0],
        "width": arr.shape[1],
        "total_pixels": int(total),
        "valid_pixels": int(valid.size),
        "valid_pct": float(valid.size / total * 100),
        "invalid_pct": float((1 - valid.size / total) * 100)
    }

    if valid.size > 0:
        result.update({
            "depth_min_valid": float(np.min(valid)),
            "depth_max_valid": float(np.max(valid)),
            "depth_mean_valid": float(np.mean(valid)),
            "depth_median_valid": float(np.median(valid)),
            "depth_std_valid": float(np.std(valid))
        })
    else:
        result.update({
            "depth_min_valid": np.nan,
            "depth_max_valid": np.nan,
            "depth_mean_valid": np.nan,
            "depth_median_valid": np.nan,
            "depth_std_valid": np.nan
        })
    return result

depth_stats_records = []

for _, row in tqdm(depth_files_to_process.iterrows(), total=len(depth_files_to_process), desc="Profundidad"):
    stats = compute_depth_stats(row["absolute_path"], MIN_VALID_DEPTH_MM, MAX_VALID_DEPTH_MM)
    depth_stats_records.append({
        "sequence": row["sequence"],
        "relative_path": row["relative_path"],
        "filename": row["filename"],
        "absolute_path": row["absolute_path"],
        **stats
    })

depth_stats_df = pd.DataFrame(depth_stats_records)
display(depth_stats_df.head())

if not depth_stats_df.empty:
    depth_sequence_summary = (
        depth_stats_df.groupby("sequence")
        .agg(
            n_depth_maps=("filename", "count"),
            mean_valid_pct=("valid_pct", "mean"),
            median_valid_pct=("valid_pct", "median"),
            mean_invalid_pct=("invalid_pct", "mean"),
            mean_depth_mm=("depth_mean_valid", "mean"),
            median_depth_mm=("depth_median_valid", "median"),
            min_depth_mm=("depth_min_valid", "min"),
            max_depth_mm=("depth_max_valid", "max"),
            mean_std_depth_mm=("depth_std_valid", "mean")
        )
        .reset_index()
    )
    numeric_cols = depth_sequence_summary.select_dtypes(include=[np.number]).columns
    depth_sequence_summary[numeric_cols] = depth_sequence_summary[numeric_cols].round(3)
else:
    depth_sequence_summary = pd.DataFrame()

display(depth_sequence_summary)

depth_stats_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_depth_stats_by_file.csv", index=False)
depth_sequence_summary.to_csv(OUTPUT_DIR / "tables" / "hamlyn_depth_summary_by_sequence.csv", index=False)
# Out:
# Profundidad:   0%|          | 0/38320 [00:00<?, ?it/s]
#       sequence                                   relative_path  \
# 0  rectified01  rectified01/rectified01/depth01/0000000000.png
# 1  rectified01  rectified01/rectified01/depth01/0000000001.png
# 2  rectified01  rectified01/rectified01/depth01/0000000002.png
# 3  rectified01  rectified01/rectified01/depth01/0000000003.png
# 4  rectified01  rectified01/rectified01/depth01/0000000004.png
#
#          filename  \
# 0  0000000000.png
# 1  0000000001.png
# 2  0000000002.png
# 3  0000000003.png
# 4  0000000004.png
#
#                                                                                                                                  absolute_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
#
#    error  height  width  total_pixels  valid_pixels  valid_pct  invalid_pct  \
# 0  False     480    640        307200        254308  82.782552    17.217448
# 1  False     480    640        307200        256241  83.411784    16.588216
# 2  False     480    640        307200        259449  84.456055    15.543945
# 3  False     480    640        307200        260880  84.921875    15.078125
# 4  False     480    640        307200        260924  84.936198    15.063802
#
#    depth_min_valid  depth_max_valid  depth_mean_valid  depth_median_valid  \
# 0             55.0            110.0         81.343445                83.0
# 1             55.0            113.0         81.384384                83.0
# 2             55.0            113.0         81.081093                82.0
# 3             55.0            109.0         81.013077                82.0
# 4             55.0            113.0         81.159508                83.0
#
#    depth_std_valid
# 0        10.380792
# 1        10.312531
# 2        10.092916
# 3        10.223222
# 4        10.230902
#       sequence  n_depth_maps  mean_valid_pct  median_valid_pct  \
# 0  rectified01          2116          72.830            75.860
# 1  rectified04          3146          53.055            53.807
# 2  rectified05          1798          46.261            46.468
# 3  rectified06          2474          79.267            81.983
# 4  rectified08         28786          35.400            35.206
#
#    mean_invalid_pct  mean_depth_mm  median_depth_mm  min_depth_mm  \
# 0            27.170         79.483             83.0           9.0
# 1            46.945         43.589             42.0          26.0
# 2            53.739         46.176             47.0          35.0
# 3            20.733        115.676            125.0          21.0
# 4            64.600         70.640             63.0          16.0
#
#    max_depth_mm  mean_std_depth_mm
# 0         300.0             11.479
# 1         300.0              3.393
# 2         300.0              3.987
# 3         300.0             20.337
# 4         300.0             14.356

# %% [markdown]
# ## 10. Estadísticas de intensidad RGB
#
# Se revisa el rango de intensidad, posible saturación y proporción de valores en cero para identificar problemas de iluminación o contraste.

# %%
depth_paths = set(depth_candidates["absolute_path"].tolist()) if not depth_candidates.empty else set()
rgb_candidates = image_meta_df[
    (~image_meta_df["absolute_path"].isin(depth_paths)) &
    (image_meta_df["extension"].isin([".jpg", ".jpeg", ".png"]))
].copy()

# Para analizar toda la base: RGB_STRIDE = 1.
RGB_STRIDE = 1
rgb_files_to_process = rgb_candidates.sort_values(["sequence", "relative_path"]).iloc[::RGB_STRIDE].copy()

print("Imágenes RGB a procesar:", len(rgb_files_to_process))
# Out:
# Imágenes RGB a procesar: 38320

# %%
def compute_rgb_stats(path):
    arr = read_image_array(path)
    if arr is None:
        return {"error": True}

    if arr.ndim == 2:
        arr = np.stack([arr, arr, arr], axis=-1)
    if arr.ndim == 3 and arr.shape[-1] == 4:
        arr = arr[..., :3]

    arr = arr.astype(np.float32)
    total_values = arr.size

    return {
        "error": False,
        "height": arr.shape[0],
        "width": arr.shape[1],
        "channels": arr.shape[2] if arr.ndim == 3 else 1,
        "min_intensity": float(np.min(arr)),
        "max_intensity": float(np.max(arr)),
        "mean_intensity": float(np.mean(arr)),
        "std_intensity": float(np.std(arr)),
        "zero_pct": float(np.sum(arr == 0) / total_values * 100),
        "saturated_255_pct": float(np.sum(arr >= 255) / total_values * 100),
        "mean_R": float(np.mean(arr[..., 0])) if arr.ndim == 3 else np.nan,
        "mean_G": float(np.mean(arr[..., 1])) if arr.ndim == 3 and arr.shape[-1] > 1 else np.nan,
        "mean_B": float(np.mean(arr[..., 2])) if arr.ndim == 3 and arr.shape[-1] > 2 else np.nan,
    }

rgb_stats_records = []

for _, row in tqdm(rgb_files_to_process.iterrows(), total=len(rgb_files_to_process), desc="RGB"):
    stats = compute_rgb_stats(row["absolute_path"])
    rgb_stats_records.append({
        "sequence": row["sequence"],
        "relative_path": row["relative_path"],
        "filename": row["filename"],
        "absolute_path": row["absolute_path"],
        **stats
    })

rgb_stats_df = pd.DataFrame(rgb_stats_records)
display(rgb_stats_df.head())

if not rgb_stats_df.empty:
    rgb_sequence_summary = (
        rgb_stats_df.groupby("sequence")
        .agg(
            n_rgb_images=("filename", "count"),
            mean_intensity=("mean_intensity", "mean"),
            std_intensity=("std_intensity", "mean"),
            min_intensity=("min_intensity", "min"),
            max_intensity=("max_intensity", "max"),
            mean_zero_pct=("zero_pct", "mean"),
            mean_saturated_255_pct=("saturated_255_pct", "mean"),
            mean_R=("mean_R", "mean"),
            mean_G=("mean_G", "mean"),
            mean_B=("mean_B", "mean")
        )
        .reset_index()
    )
    numeric_cols = rgb_sequence_summary.select_dtypes(include=[np.number]).columns
    rgb_sequence_summary[numeric_cols] = rgb_sequence_summary[numeric_cols].round(3)
else:
    rgb_sequence_summary = pd.DataFrame()

display(rgb_sequence_summary)

rgb_stats_df.to_csv(OUTPUT_DIR / "tables" / "hamlyn_rgb_stats_by_file.csv", index=False)
rgb_sequence_summary.to_csv(OUTPUT_DIR / "tables" / "hamlyn_rgb_summary_by_sequence.csv", index=False)
# Out:
# RGB:   0%|          | 0/38320 [00:00<?, ?it/s]
#       sequence                                   relative_path  \
# 0  rectified01  rectified01/rectified01/image01/0000000000.jpg
# 1  rectified01  rectified01/rectified01/image01/0000000001.jpg
# 2  rectified01  rectified01/rectified01/image01/0000000002.jpg
# 3  rectified01  rectified01/rectified01/image01/0000000003.jpg
# 4  rectified01  rectified01/rectified01/image01/0000000004.jpg
#
#          filename  \
# 0  0000000000.jpg
# 1  0000000001.jpg
# 2  0000000002.jpg
# 3  0000000003.jpg
# 4  0000000004.jpg
#
#                                                                                                                                  absolute_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
#
#    error  height  width  channels  min_intensity  max_intensity  \
# 0  False     480    640         3            0.0          255.0
# 1  False     480    640         3            0.0          255.0
# 2  False     480    640         3            0.0          255.0
# 3  False     480    640         3            0.0          255.0
# 4  False     480    640         3            0.0          255.0
#
#    mean_intensity  std_intensity  zero_pct  saturated_255_pct      mean_R  \
# 0      100.135750      47.241112  4.580946           0.003798  132.469864
# 1      100.788177      47.441814  4.586480           0.003038  133.202957
# 2      100.716316      47.348232  4.583442           0.003147  132.986404
# 3      100.190529      47.235149  4.597656           0.002930  132.517365
# 4      100.849876      47.453373  4.593207           0.004123  133.245682
#
#       mean_G     mean_B
# 0  85.786758  82.150627
# 1  86.386902  82.774673
# 2  86.357727  82.804688
# 3  85.848640  82.205612
# 4  86.536186  82.767761
#       sequence  n_rgb_images  mean_intensity  std_intensity  min_intensity  \
# 0  rectified01          2116          95.099         46.361            0.0
# 1  rectified04          3146          74.209         60.409            0.0
# 2  rectified05          1798          82.562         65.525            0.0
# 3  rectified06          2474         106.653         45.431            0.0
# 4  rectified08         28786          81.598         50.614            0.0
#
#    max_intensity  mean_zero_pct  mean_saturated_255_pct   mean_R  mean_G  \
# 0          255.0          4.500                   0.001  125.145  81.567
# 1          255.0          5.163                   0.471  122.091  51.134
# 2          255.0          4.751                   0.851  114.752  68.531
# 3          255.0          4.298                   0.012  138.626  91.897
# 4          255.0          4.552                   0.010  111.999  67.029
#
#    mean_B
# 0  78.584
# 1  49.402
# 2  64.403
# 3  89.437
# 4  65.766

# %% [markdown]
# ## 11. Visualizaciones de control por secuencia
#
# Se genera una figura por secuencia con:
#
# 1. imagen RGB;
# 2. mapa de profundidad normalizado;
# 3. máscara de profundidad válida;
# 4. histograma de profundidad válida.

# %%
def choose_sample_file(df, sequence):
    subset = df[df["sequence"] == sequence].copy()
    if subset.empty:
        return None
    subset = subset.sort_values("relative_path")
    return subset.iloc[len(subset)//2]["absolute_path"]

sample_pairs = []
for seq in expected_sequences:
    sample_pairs.append({
        "sequence": seq,
        "rgb_path": choose_sample_file(rgb_files_to_process, seq),
        "depth_path": choose_sample_file(depth_files_to_process, seq)
    })

sample_pairs_df = pd.DataFrame(sample_pairs)
display(sample_pairs_df)
# Out:
#       sequence  \
# 0  rectified01
# 1  rectified04
# 2  rectified05
# 3  rectified06
# 4  rectified08
#
#                                                                                                                                       rgb_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified05/rectified05/im...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified06/rectified06/im...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified08/rectified08/im...
#
#                                                                                                                                     depth_path
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/de...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified05/rectified05/de...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified06/rectified06/de...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified08/rectified08/de...

# %%
def normalize_for_display(arr, valid_mask=None):
    arr = arr.astype(np.float32)
    vals = arr[valid_mask] if valid_mask is not None and np.any(valid_mask) else arr[np.isfinite(arr)]
    if vals.size == 0:
        return np.zeros_like(arr, dtype=np.float32)
    p1, p99 = np.percentile(vals, [1, 99])
    if p99 <= p1:
        return np.zeros_like(arr, dtype=np.float32)
    return np.clip((arr - p1) / (p99 - p1), 0, 1)

def plot_sequence_control(sequence, rgb_path, depth_path, save=True):
    if rgb_path is None or depth_path is None:
        print(f"No hay suficientes archivos para {sequence}.")
        return

    rgb = read_image_array(rgb_path)
    depth = read_image_array(depth_path)
    if rgb is None or depth is None:
        print(f"Error leyendo archivos para {sequence}.")
        return

    rgb_disp = rgb if rgb.ndim == 2 else rgb[..., :3]
    if depth.ndim == 3:
        depth = depth[..., 0]
    depth = depth.astype(np.float32)

    valid_mask = np.isfinite(depth) & (depth >= MIN_VALID_DEPTH_MM) & (depth <= MAX_VALID_DEPTH_MM)
    depth_norm = normalize_for_display(depth, valid_mask)
    valid_depth = depth[valid_mask]

    fig = plt.figure(figsize=(18, 5))

    ax1 = plt.subplot(1, 4, 1)
    ax1.imshow(rgb_disp)
    ax1.set_title(f"{sequence}\nImagen RGB")
    ax1.axis("off")

    ax2 = plt.subplot(1, 4, 2)
    ax2.imshow(depth_norm)
    ax2.set_title("Mapa de profundidad\nnormalizado")
    ax2.axis("off")

    ax3 = plt.subplot(1, 4, 3)
    ax3.imshow(valid_mask)
    ax3.set_title(f"Máscara válida\n{valid_mask.mean()*100:.2f}% válido")
    ax3.axis("off")

    ax4 = plt.subplot(1, 4, 4)
    if valid_depth.size > 0:
        ax4.hist(valid_depth.flatten(), bins=60)
        ax4.set_title("Histograma de profundidad válida")
        ax4.set_xlabel("Profundidad (mm)")
        ax4.set_ylabel("Frecuencia")
    else:
        ax4.text(0.5, 0.5, "Sin profundidad válida", ha="center", va="center")
        ax4.set_axis_off()

    plt.tight_layout()

    if save:
        out_path = OUTPUT_DIR / "figures" / f"{sequence}_control_visual.png"
        fig.savefig(out_path, dpi=160, bbox_inches="tight")
        print("Figura guardada:", out_path)

    plt.show()

for _, row in sample_pairs_df.iterrows():
    plot_sequence_control(row["sequence"], row["rgb_path"], row["depth_path"])

# %% [markdown]
# ## 12. Gráficas agregadas entre secuencias
#
# Estas gráficas resumen diferencias entre secuencias: proporción de profundidad válida, profundidad media e intensidad promedio.

# %%
def save_barplot(df, x, y, title, ylabel, filename):
    if df.empty or x not in df.columns or y not in df.columns:
        print(f"No hay datos para {title}")
        return

    plt.figure(figsize=(10, 5))
    plt.bar(df[x].astype(str), df[y])
    plt.title(title)
    plt.xlabel("Secuencia")
    plt.ylabel(ylabel)
    plt.tight_layout()
    out_path = OUTPUT_DIR / "figures" / filename
    plt.savefig(out_path, dpi=160, bbox_inches="tight")
    plt.show()
    print("Figura guardada:", out_path)

save_barplot(depth_sequence_summary, "sequence", "mean_valid_pct",
             "Porcentaje promedio de píxeles válidos por secuencia",
             "% píxeles válidos", "mean_valid_pct_by_sequence.png")

save_barplot(depth_sequence_summary, "sequence", "mean_depth_mm",
             "Profundidad media válida por secuencia",
             "Profundidad media (mm)", "mean_depth_by_sequence.png")

save_barplot(rgb_sequence_summary, "sequence", "mean_intensity",
             "Intensidad promedio RGB por secuencia",
             "Intensidad promedio", "mean_rgb_intensity_by_sequence.png")

# %% [markdown]
# ## 13. Detección preliminar de valores atípicos
#
# Se identifican archivos con bajo porcentaje de profundidad válida, saturación elevada o demasiados valores en cero.

# %%
LOW_VALID_THRESHOLD = 50
HIGH_SATURATION_THRESHOLD = 5
HIGH_ZERO_THRESHOLD = 5

depth_outliers = depth_stats_df[
    (depth_stats_df["valid_pct"] < LOW_VALID_THRESHOLD)
].copy() if not depth_stats_df.empty else pd.DataFrame()

rgb_outliers = rgb_stats_df[
    (rgb_stats_df["saturated_255_pct"] > HIGH_SATURATION_THRESHOLD) |
    (rgb_stats_df["zero_pct"] > HIGH_ZERO_THRESHOLD)
].copy() if not rgb_stats_df.empty else pd.DataFrame()

print("Posibles outliers en profundidad:", len(depth_outliers))
print("Posibles outliers RGB:", len(rgb_outliers))

display(depth_outliers.head(20))
display(rgb_outliers.head(20))

depth_outliers.to_csv(OUTPUT_DIR / "tables" / "hamlyn_depth_possible_outliers.csv", index=False)
rgb_outliers.to_csv(OUTPUT_DIR / "tables" / "hamlyn_rgb_possible_outliers.csv", index=False)
# Out:
# Posibles outliers en profundidad: 26740
# Posibles outliers RGB: 18212
#         sequence                                   relative_path  \
# 186  rectified01  rectified01/rectified01/depth01/0000000186.png
# 740  rectified01  rectified01/rectified01/depth01/0000000740.png
# 744  rectified01  rectified01/rectified01/depth01/0000000744.png
# 745  rectified01  rectified01/rectified01/depth01/0000000745.png
# 749  rectified01  rectified01/rectified01/depth01/0000000749.png
# 750  rectified01  rectified01/rectified01/depth01/0000000750.png
# 751  rectified01  rectified01/rectified01/depth01/0000000751.png
# 753  rectified01  rectified01/rectified01/depth01/0000000753.png
# 754  rectified01  rectified01/rectified01/depth01/0000000754.png
# 755  rectified01  rectified01/rectified01/depth01/0000000755.png
# 756  rectified01  rectified01/rectified01/depth01/0000000756.png
# 757  rectified01  rectified01/rectified01/depth01/0000000757.png
# 758  rectified01  rectified01/rectified01/depth01/0000000758.png
# 759  rectified01  rectified01/rectified01/depth01/0000000759.png
# 760  rectified01  rectified01/rectified01/depth01/0000000760.png
# 761  rectified01  rectified01/rectified01/depth01/0000000761.png
# 762  rectified01  rectified01/rectified01/depth01/0000000762.png
# 763  rectified01  rectified01/rectified01/depth01/0000000763.png
# 764  rectified01  rectified01/rectified01/depth01/0000000764.png
# 765  rectified01  rectified01/rectified01/depth01/0000000765.png
#
#            filename  \
# 186  0000000186.png
# 740  0000000740.png
# 744  0000000744.png
# 745  0000000745.png
# 749  0000000749.png
# 750  0000000750.png
# 751  0000000751.png
# 753  0000000753.png
# 754  0000000754.png
# 755  0000000755.png
# 756  0000000756.png
# 757  0000000757.png
# 758  0000000758.png
# 759  0000000759.png
# 760  0000000760.png
# 761  0000000761.png
# 762  0000000762.png
# 763  0000000763.png
# 764  0000000764.png
# 765  0000000765.png
#
#                                                                                                                                    absolute_path  \
# 186  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 740  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 744  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 745  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 749  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 750  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 751  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 753  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 754  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 755  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 756  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 757  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 758  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 759  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 760  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 761  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 762  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 763  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 764  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 765  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
#
#      error  height  width  total_pixels  valid_pixels  valid_pct  invalid_pct  \
# 186  False     480    640        307200        148610  48.375651    51.624349
# 740  False     480    640        307200        146311  47.627279    52.372721
# 744  False     480    640        307200        147013  47.855794    52.144206
# 745  False     480    640        307200        142449  46.370117    53.629883
# 749  False     480    640        307200        123045  40.053711    59.946289
# 750  False     480    640        307200        146237  47.603190    52.396810
# 751  False     480    640        307200        129013  41.996419    58.003581
# 753  False     480    640        307200        106263  34.590820    65.409180
# 754  False     480    640        307200        117092  38.115885    61.884115
# 755  False     480    640        307200        153269  49.892253    50.107747
# 756  False     480    640        307200        122701  39.941732    60.058268
# 757  False     480    640        307200        140461  45.722982    54.277018
# 758  False     480    640        307200        119048  38.752604    61.247396
# 759  False     480    640        307200         78505  25.555013    74.444987
# 760  False     480    640        307200        107026  34.839193    65.160807
# 761  False     480    640        307200        116441  37.903971    62.096029
# 762  False     480    640        307200        120337  39.172201    60.827799
# 763  False     480    640        307200         92777  30.200846    69.799154
# 764  False     480    640        307200        137069  44.618815    55.381185
# 765  False     480    640        307200        138686  45.145182    54.854818
#
#      depth_min_valid  depth_max_valid  depth_mean_valid  depth_median_valid  \
# 186             72.0            127.0         96.665344                98.0
# 740             55.0            114.0         88.505447                90.0
# 744             54.0            120.0         87.373924                88.0
# 745             55.0            119.0         88.375854                88.0
# 749             55.0            125.0         87.699944                88.0
# 750             57.0            127.0         85.487091                87.0
# 751             55.0            300.0        100.193581                93.0
# 753             56.0            114.0         88.515915                90.0
# 754             59.0            128.0         88.030602                90.0
# 755             57.0            300.0         85.727196                87.0
# 756             59.0            300.0         89.857872                89.0
# 757             59.0            129.0         87.495270                89.0
# 758             55.0            115.0         89.073692                90.0
# 759             62.0            111.0         89.292603                90.0
# 760             54.0            120.0         89.597115                90.0
# 761             54.0            121.0         87.901421                90.0
# 762             57.0            114.0         83.795990                85.0
# 763             74.0            114.0         92.045288                91.0
# 764             57.0            115.0         85.389374                87.0
# 765             64.0            129.0         91.993111                91.0
#
#      depth_std_valid
# 186         8.544146
# 740        11.336042
# 744        12.634953
# 745        12.142122
# 749        12.727302
# 750        12.277616
# 751        30.846550
# 753        10.759859
# 754        10.965593
# 755        13.221585
# 756        14.600746
# 757        11.187359
# 758         9.508973
# 759         6.460801
# 760         8.390626
# 761        10.513819
# 762        11.237695
# 763         6.206708
# 764        12.064990
# 765         7.677141
#          sequence                                   relative_path  \
# 3689  rectified04  rectified04/rectified04/image02/0000000000.jpg
# 3690  rectified04  rectified04/rectified04/image02/0000000001.jpg
# 3691  rectified04  rectified04/rectified04/image02/0000000002.jpg
# 3692  rectified04  rectified04/rectified04/image02/0000000003.jpg
# 3693  rectified04  rectified04/rectified04/image02/0000000004.jpg
# 3694  rectified04  rectified04/rectified04/image02/0000000005.jpg
# 3695  rectified04  rectified04/rectified04/image02/0000000006.jpg
# 3696  rectified04  rectified04/rectified04/image02/0000000007.jpg
# 3697  rectified04  rectified04/rectified04/image02/0000000008.jpg
# 3698  rectified04  rectified04/rectified04/image02/0000000009.jpg
# 3699  rectified04  rectified04/rectified04/image02/0000000010.jpg
# 3700  rectified04  rectified04/rectified04/image02/0000000011.jpg
# 3701  rectified04  rectified04/rectified04/image02/0000000012.jpg
# 3702  rectified04  rectified04/rectified04/image02/0000000013.jpg
# 3703  rectified04  rectified04/rectified04/image02/0000000014.jpg
# 3704  rectified04  rectified04/rectified04/image02/0000000015.jpg
# 3705  rectified04  rectified04/rectified04/image02/0000000016.jpg
# 3706  rectified04  rectified04/rectified04/image02/0000000017.jpg
# 3707  rectified04  rectified04/rectified04/image02/0000000018.jpg
# 3708  rectified04  rectified04/rectified04/image02/0000000019.jpg
#
#             filename  \
# 3689  0000000000.jpg
# 3690  0000000001.jpg
# 3691  0000000002.jpg
# 3692  0000000003.jpg
# 3693  0000000004.jpg
# 3694  0000000005.jpg
# 3695  0000000006.jpg
# 3696  0000000007.jpg
# 3697  0000000008.jpg
# 3698  0000000009.jpg
# 3699  0000000010.jpg
# 3700  0000000011.jpg
# 3701  0000000012.jpg
# 3702  0000000013.jpg
# 3703  0000000014.jpg
# 3704  0000000015.jpg
# 3705  0000000016.jpg
# 3706  0000000017.jpg
# 3707  0000000018.jpg
# 3708  0000000019.jpg
#
#                                                                                                                                     absolute_path  \
# 3689  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3690  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3691  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3692  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3693  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3694  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3695  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3696  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3697  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3698  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3699  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3700  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3701  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3702  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3703  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3704  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3705  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3706  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3707  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
# 3708  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified04/rectified04/im...
#
#       error  height  width  channels  min_intensity  max_intensity  \
# 3689  False     288    360         3            0.0          255.0
# 3690  False     288    360         3            0.0          255.0
# 3691  False     288    360         3            0.0          255.0
# 3692  False     288    360         3            0.0          255.0
# 3693  False     288    360         3            0.0          255.0
# 3694  False     288    360         3            0.0          255.0
# 3695  False     288    360         3            0.0          255.0
# 3696  False     288    360         3            0.0          255.0
# 3697  False     288    360         3            0.0          255.0
# 3698  False     288    360         3            0.0          255.0
# 3699  False     288    360         3            0.0          255.0
# 3700  False     288    360         3            0.0          255.0
# 3701  False     288    360         3            0.0          255.0
# 3702  False     288    360         3            0.0          255.0
# 3703  False     288    360         3            0.0          255.0
# 3704  False     288    360         3            0.0          255.0
# 3705  False     288    360         3            0.0          255.0
# 3706  False     288    360         3            0.0          255.0
# 3707  False     288    360         3            0.0          255.0
# 3708  False     288    360         3            0.0          255.0
#
#       mean_intensity  std_intensity  zero_pct  saturated_255_pct      mean_R  \
# 3689       73.705765      62.723499  8.226273           0.656507  123.406204
# 3690       73.812401      61.223854  7.686471           0.708591  122.723282
# 3691       73.505089      61.212997  7.591307           0.817258  122.413857
# 3692       74.038177      61.913712  7.338606           0.995049  121.859497
# 3693       72.790161      61.644127  7.248907           0.927533  119.765182
# 3694       73.892242      62.520798  7.262088           1.059671  119.927864
# 3695       73.456665      62.759727  7.258230           1.036201  118.985649
# 3696       73.011543      63.333549  7.233475           1.065458  117.929352
# 3697       73.520332      63.226871  7.312886           0.991834  118.714066
# 3698       73.031601      63.724224  7.479745           0.833655  119.048431
# 3699       73.011482      64.487640  7.805427           0.776427  119.310463
# 3700       73.467133      64.574287  7.891268           0.614069  120.705238
# 3701       73.152756      64.045937  8.051376           0.516332  120.490540
# 3702       72.424187      63.899685  8.065201           0.577739  119.712349
# 3703       69.455078      61.707428  8.538452           0.519869  116.618294
# 3704       68.422867      60.579887  8.636510           0.565844  115.212036
# 3705       68.667885      60.092369  8.553241           0.530157  115.179237
# 3706       68.581131      60.012959  8.538130           0.433706  115.531502
# 3707       68.464722      59.893383  8.865741           0.373585  115.863937
# 3708       68.373520      59.747509  9.080183           0.319895  116.279976
#
#          mean_G     mean_B
# 3689  49.991531  47.719540
# 3690  50.452930  48.260975
# 3691  50.212086  47.889324
# 3692  51.203693  49.051361
# 3693  50.196999  48.408283
# 3694  51.594395  50.154503
# 3695  51.313251  50.071037
# 3696  51.055199  50.050056
# 3697  51.369156  50.477806
# 3698  50.603973  49.442410
# 3699  50.295822  49.428143
# 3700  50.352875  49.343307
# 3701  50.049683  48.918037
# 3702  49.532833  48.027355
# 3703  46.961689  44.785233
# 3704  46.387325  43.669243
# 3705  47.102036  43.722424
# 3706  46.877014  43.334877
# 3707  46.549343  42.980892
# 3708  46.198208  42.642380

# %% [markdown]
# ## 14. Resumen ejecutivo automático
#
# Esta celda genera un texto base para redactar el apartado HAMLYN del reporte.

# %%
def generate_summary_text():
    lines = []
    lines.append("Resumen exploratorio del dataset HAMLYN rectificado")
    lines.append("="*60)
    lines.append("")

    if not files_df.empty:
        lines.append(f"Se identificaron {len(files_df):,} archivos descomprimidos dentro de data/hamlyn/extracted.")
        lines.append(f"El tamaño total aproximado de archivos analizados es de {files_df['size_mb'].sum():,.2f} MB.")

    if not image_meta_df.empty:
        lines.append(f"Se inspeccionaron {len(image_meta_df):,} archivos de imagen.")
        seqs = sorted(image_meta_df["sequence"].dropna().unique())
        lines.append(f"Las secuencias detectadas fueron: {', '.join(seqs)}.")

    if not rgb_sequence_summary.empty:
        lines.append("")
        lines.append("Imágenes RGB:")
        for _, row in rgb_sequence_summary.iterrows():
            lines.append(
                f"- {row['sequence']}: {int(row['n_rgb_images']):,} imágenes RGB, "
                f"intensidad media {row['mean_intensity']:.2f}, "
                f"saturación promedio {row['mean_saturated_255_pct']:.3f}%."
            )

    if not depth_sequence_summary.empty:
        lines.append("")
        lines.append("Mapas de profundidad:")
        for _, row in depth_sequence_summary.iterrows():
            lines.append(
                f"- {row['sequence']}: {int(row['n_depth_maps']):,} mapas de profundidad, "
                f"{row['mean_valid_pct']:.2f}% de píxeles válidos en promedio, "
                f"profundidad media {row['mean_depth_mm']:.2f} mm."
            )

    lines.append("")
    lines.append("Interpretación metodológica preliminar:")
    lines.append(
        "HAMLYN rectificado permite trabajar con pares estéreo alineados y mapas de profundidad asociados. "
        "Esto facilita el análisis exploratorio, la comparación entre secuencias y la preparación de datos "
        "para modelos de estimación de profundidad. A diferencia de SCARED, cuya profundidad de referencia "
        "se obtiene mediante luz estructurada, la versión rectificada de HAMLYN debe documentarse como una "
        "base preprocesada orientada a facilitar correspondencia estéreo y entrenamiento computacional."
    )

    return "\n".join(lines)

summary_text = generate_summary_text()
print(summary_text)

summary_path = OUTPUT_DIR / "hamlyn_resumen_ejecutivo.txt"
summary_path.write_text(summary_text, encoding="utf-8")
print("\nResumen exportado:", summary_path)
# Out:
# Resumen exploratorio del dataset HAMLYN rectificado
# ============================================================
#
# Se identificaron 76,640 archivos descomprimidos dentro de data/hamlyn/extracted.
# El tamaño total aproximado de archivos analizados es de 2,898.07 MB.
# Se inspeccionaron 76,640 archivos de imagen.
# Las secuencias detectadas fueron: rectified01, rectified04, rectified05, rectified06, rectified08.
#
# Imágenes RGB:
# - rectified01: 2,116 imágenes RGB, intensidad media 95.10, saturación promedio 0.001%.
# - rectified04: 3,146 imágenes RGB, intensidad media 74.21, saturación promedio 0.471%.
# - rectified05: 1,798 imágenes RGB, intensidad media 82.56, saturación promedio 0.851%.
# - rectified06: 2,474 imágenes RGB, intensidad media 106.65, saturación promedio 0.012%.
# - rectified08: 28,786 imágenes RGB, intensidad media 81.60, saturación promedio 0.010%.
#
# Mapas de profundidad:
# - rectified01: 2,116 mapas de profundidad, 72.83% de píxeles válidos en promedio, profundidad media 79.48 mm.
# - rectified04: 3,146 mapas de profundidad, 53.05% de píxeles válidos en promedio, profundidad media 43.59 mm.
# - rectified05: 1,798 mapas de profundidad, 46.26% de píxeles válidos en promedio, profundidad media 46.18 mm.
# - rectified06: 2,474 mapas de profundidad, 79.27% de píxeles válidos en promedio, profundidad media 115.68 mm.
# - rectified08: 28,786 mapas de profundidad, 35.40% de píxeles válidos en promedio, profundidad media 70.64 mm.
#
# Interpretación metodológica preliminar:
# HAMLYN rectificado permite trabajar con pares estéreo alineados y mapas de profundidad asociados. Esto facilita el análisis exploratorio, la comparación entre secuencias y la preparación de datos para modelos de estimación de profundidad. A diferencia de SCARED, cuya profundidad de referencia se obtiene mediante luz estructurada, la versión rectificada de HAMLYN debe documentarse como una base preprocesada orientada a facilitar correspondencia estéreo y entrenamiento computacional.
#
# Resumen exportado: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn/hamlyn_resumen_ejecutivo.txt

# %% [markdown]
# ## 15. Salidas generadas
#
# Al finalizar la ejecución, el notebook crea:
#
# ```text
# outputs/hamlyn/
# ├── tables/
# │   ├── hamlyn_download_inventory.csv
# │   ├── hamlyn_all_files_inventory.csv
# │   ├── hamlyn_filetype_summary.csv
# │   ├── hamlyn_image_metadata.csv
# │   ├── hamlyn_resolution_summary.csv
# │   ├── hamlyn_depth_probe.csv
# │   ├── hamlyn_depth_candidates.csv
# │   ├── hamlyn_depth_stats_by_file.csv
# │   ├── hamlyn_depth_summary_by_sequence.csv
# │   ├── hamlyn_rgb_stats_by_file.csv
# │   ├── hamlyn_rgb_summary_by_sequence.csv
# │   ├── hamlyn_depth_possible_outliers.csv
# │   └── hamlyn_rgb_possible_outliers.csv
# │
# ├── figures/
# │   ├── rectifiedXX_control_visual.png
# │   ├── mean_valid_pct_by_sequence.png
# │   ├── mean_depth_by_sequence.png
# │   └── mean_rgb_intensity_by_sequence.png
# │
# └── hamlyn_resumen_ejecutivo.txt
# ```

# %% [markdown]
# ## 15. Análisis temporal por secuencia
#
# Dado que HAMLYN está organizado como un conjunto de secuencias de imágenes endoscópicas, es posible analizar si las propiedades visuales y geométricas cambian a lo largo del tiempo.
#
# En esta sección se construye un índice aproximado de frame a partir del orden de los archivos y se analizan tres variables:
#
# 1. intensidad promedio RGB;
# 2. porcentaje de píxeles de profundidad válida;
# 3. profundidad media válida.
#
# Este análisis permite responder si existen tendencias temporales dentro de las secuencias, lo cual es relevante porque los videos endoscópicos pueden presentar cambios progresivos por movimiento de cámara, deformación del tejido, presencia de instrumentos, cambios de iluminación, humo, sangre, oclusiones o reflejos especulares.

# %%
def add_frame_index(df, sequence_col="sequence", path_col="relative_path"):
    """
    Agrega un índice temporal aproximado por secuencia.
    Se usa el orden alfabético/natural de los archivos como aproximación al orden de frames.
    """
    if df.empty:
        return df.copy()
    
    out = df.copy()
    out = out.sort_values([sequence_col, path_col]).reset_index(drop=True)
    out["frame_index"] = out.groupby(sequence_col).cumcount()
    return out

rgb_temporal_df = add_frame_index(rgb_stats_df)
depth_temporal_df = add_frame_index(depth_stats_df)

print("Registros temporales RGB:", len(rgb_temporal_df))
print("Registros temporales profundidad:", len(depth_temporal_df))

display(rgb_temporal_df.head())
display(depth_temporal_df.head())
# Out:
# Registros temporales RGB: 38320
# Registros temporales profundidad: 38320
#       sequence                                   relative_path  \
# 0  rectified01  rectified01/rectified01/image01/0000000000.jpg
# 1  rectified01  rectified01/rectified01/image01/0000000001.jpg
# 2  rectified01  rectified01/rectified01/image01/0000000002.jpg
# 3  rectified01  rectified01/rectified01/image01/0000000003.jpg
# 4  rectified01  rectified01/rectified01/image01/0000000004.jpg
#
#          filename  \
# 0  0000000000.jpg
# 1  0000000001.jpg
# 2  0000000002.jpg
# 3  0000000003.jpg
# 4  0000000004.jpg
#
#                                                                                                                                  absolute_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/im...
#
#    error  height  width  channels  min_intensity  max_intensity  \
# 0  False     480    640         3            0.0          255.0
# 1  False     480    640         3            0.0          255.0
# 2  False     480    640         3            0.0          255.0
# 3  False     480    640         3            0.0          255.0
# 4  False     480    640         3            0.0          255.0
#
#    mean_intensity  std_intensity  zero_pct  saturated_255_pct      mean_R  \
# 0      100.135750      47.241112  4.580946           0.003798  132.469864
# 1      100.788177      47.441814  4.586480           0.003038  133.202957
# 2      100.716316      47.348232  4.583442           0.003147  132.986404
# 3      100.190529      47.235149  4.597656           0.002930  132.517365
# 4      100.849876      47.453373  4.593207           0.004123  133.245682
#
#       mean_G     mean_B  frame_index
# 0  85.786758  82.150627            0
# 1  86.386902  82.774673            1
# 2  86.357727  82.804688            2
# 3  85.848640  82.205612            3
# 4  86.536186  82.767761            4
#       sequence                                   relative_path  \
# 0  rectified01  rectified01/rectified01/depth01/0000000000.png
# 1  rectified01  rectified01/rectified01/depth01/0000000001.png
# 2  rectified01  rectified01/rectified01/depth01/0000000002.png
# 3  rectified01  rectified01/rectified01/depth01/0000000003.png
# 4  rectified01  rectified01/rectified01/depth01/0000000004.png
#
#          filename  \
# 0  0000000000.png
# 1  0000000001.png
# 2  0000000002.png
# 3  0000000003.png
# 4  0000000004.png
#
#                                                                                                                                  absolute_path  \
# 0  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 1  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 2  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 3  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
# 4  /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/data/hamlyn/extracted/rectified01/rectified01/de...
#
#    error  height  width  total_pixels  valid_pixels  valid_pct  invalid_pct  \
# 0  False     480    640        307200        254308  82.782552    17.217448
# 1  False     480    640        307200        256241  83.411784    16.588216
# 2  False     480    640        307200        259449  84.456055    15.543945
# 3  False     480    640        307200        260880  84.921875    15.078125
# 4  False     480    640        307200        260924  84.936198    15.063802
#
#    depth_min_valid  depth_max_valid  depth_mean_valid  depth_median_valid  \
# 0             55.0            110.0         81.343445                83.0
# 1             55.0            113.0         81.384384                83.0
# 2             55.0            113.0         81.081093                82.0
# 3             55.0            109.0         81.013077                82.0
# 4             55.0            113.0         81.159508                83.0
#
#    depth_std_valid  frame_index
# 0        10.380792            0
# 1        10.312531            1
# 2        10.092916            2
# 3        10.223222            3
# 4        10.230902            4

# %%
def plot_temporal_metric(df, metric, ylabel, title, filename):
    """
    Genera una gráfica temporal por secuencia para una métrica dada.
    """
    if df.empty or metric not in df.columns:
        print(f"No hay datos suficientes para graficar: {metric}")
        return
    
    plt.figure(figsize=(12, 6))
    
    for seq in sorted(df["sequence"].dropna().unique()):
        subset = df[df["sequence"] == seq].copy()
        subset = subset.sort_values("frame_index")
        
        # Para secuencias muy grandes, se suaviza con media móvil para mejorar lectura visual.
        y = subset[metric]
        if len(subset) > 500:
            y = y.rolling(window=100, min_periods=1).mean()
        
        plt.plot(subset["frame_index"], y, label=seq, linewidth=1)
    
    plt.title(title)
    plt.xlabel("Índice aproximado de frame")
    plt.ylabel(ylabel)
    plt.legend()
    plt.tight_layout()
    
    out_path = OUTPUT_DIR / "figures" / filename
    plt.savefig(out_path, dpi=160, bbox_inches="tight")
    plt.show()
    
    print("Figura guardada:", out_path)

plot_temporal_metric(
    rgb_temporal_df,
    metric="mean_intensity",
    ylabel="Intensidad promedio RGB",
    title="Tendencia temporal de intensidad promedio por secuencia",
    filename="temporal_mean_rgb_intensity_by_sequence.png"
)

plot_temporal_metric(
    depth_temporal_df,
    metric="valid_pct",
    ylabel="% de píxeles válidos",
    title="Tendencia temporal de profundidad válida por secuencia",
    filename="temporal_valid_depth_pct_by_sequence.png"
)

plot_temporal_metric(
    depth_temporal_df,
    metric="depth_mean_valid",
    ylabel="Profundidad media válida (mm)",
    title="Tendencia temporal de profundidad media por secuencia",
    filename="temporal_mean_depth_by_sequence.png"
)

# %%
# Resumen temporal por secuencia: variabilidad y tendencia lineal aproximada.

def temporal_slope(x, y):
    """
    Calcula pendiente lineal simple para aproximar tendencia temporal.
    Si no hay suficientes datos, devuelve NaN.
    """
    valid = np.isfinite(x) & np.isfinite(y)
    x = np.asarray(x)[valid]
    y = np.asarray(y)[valid]
    
    if len(x) < 2:
        return np.nan
    
    slope, intercept = np.polyfit(x, y, 1)
    return slope

temporal_summary_records = []

for seq in expected_sequences:
    rgb_seq = rgb_temporal_df[rgb_temporal_df["sequence"] == seq].copy()
    depth_seq = depth_temporal_df[depth_temporal_df["sequence"] == seq].copy()
    
    record = {"sequence": seq}
    
    if not rgb_seq.empty:
        record.update({
            "rgb_mean_intensity_mean": rgb_seq["mean_intensity"].mean(),
            "rgb_mean_intensity_std": rgb_seq["mean_intensity"].std(),
            "rgb_mean_intensity_slope": temporal_slope(
                rgb_seq["frame_index"].values,
                rgb_seq["mean_intensity"].values
            )
        })
    else:
        record.update({
            "rgb_mean_intensity_mean": np.nan,
            "rgb_mean_intensity_std": np.nan,
            "rgb_mean_intensity_slope": np.nan
        })
    
    if not depth_seq.empty:
        record.update({
            "depth_valid_pct_mean": depth_seq["valid_pct"].mean(),
            "depth_valid_pct_std": depth_seq["valid_pct"].std(),
            "depth_valid_pct_slope": temporal_slope(
                depth_seq["frame_index"].values,
                depth_seq["valid_pct"].values
            ),
            "depth_mean_valid_mean": depth_seq["depth_mean_valid"].mean(),
            "depth_mean_valid_std": depth_seq["depth_mean_valid"].std(),
            "depth_mean_valid_slope": temporal_slope(
                depth_seq["frame_index"].values,
                depth_seq["depth_mean_valid"].values
            )
        })
    else:
        record.update({
            "depth_valid_pct_mean": np.nan,
            "depth_valid_pct_std": np.nan,
            "depth_valid_pct_slope": np.nan,
            "depth_mean_valid_mean": np.nan,
            "depth_mean_valid_std": np.nan,
            "depth_mean_valid_slope": np.nan
        })
    
    temporal_summary_records.append(record)

hamlyn_temporal_summary = pd.DataFrame(temporal_summary_records)

numeric_cols = hamlyn_temporal_summary.select_dtypes(include=[np.number]).columns
hamlyn_temporal_summary[numeric_cols] = hamlyn_temporal_summary[numeric_cols].round(6)

display(hamlyn_temporal_summary)

hamlyn_temporal_summary.to_csv(
    OUTPUT_DIR / "tables" / "hamlyn_temporal_summary_by_sequence.csv",
    index=False
)

print("Tabla temporal exportada:", OUTPUT_DIR / "tables" / "hamlyn_temporal_summary_by_sequence.csv")
# Out:
#       sequence  rgb_mean_intensity_mean  rgb_mean_intensity_std  \
# 0  rectified01                95.098819                6.398720
# 1  rectified04                74.209075                4.040758
# 2  rectified05                82.562041                2.723541
# 3  rectified06               106.653209               11.777616
# 4  rectified08                81.598142               14.126522
#
#    rgb_mean_intensity_slope  depth_valid_pct_mean  depth_valid_pct_std  \
# 0                 -0.001838             72.829547            11.016347
# 1                 -0.001821             53.055025             5.308721
# 2                 -0.003216             46.261157             4.759381
# 3                 -0.005556             79.266968             7.488887
# 4                 -0.000167             35.399764            13.203347
#
#    depth_valid_pct_slope  depth_mean_valid_mean  depth_mean_valid_std  \
# 0              -0.003577              79.483333             12.712294
# 1              -0.001674              43.588982              3.177854
# 2              -0.001878              46.176285              0.712394
# 3               0.000405             115.675781             28.434815
# 4              -0.000461              70.640425             18.485113
#
#    depth_mean_valid_slope
# 0               -0.003347
# 1                0.001362
# 2               -0.000008
# 3                0.004132
# 4               -0.000725
# Tabla temporal exportada: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn/tables/hamlyn_temporal_summary_by_sequence.csv

# %% [markdown]
# ## 16. Correlación exploratoria entre variables visuales y geométricas
#
# Aunque HAMLYN no es una base tabular tradicional, es posible construir variables resumidas por frame para explorar relaciones entre calidad visual y calidad geométrica.
#
# En esta sección se integran métricas RGB y métricas de profundidad por secuencia e índice de frame. Posteriormente se calcula una matriz de correlación entre:
#
# - intensidad promedio RGB;
# - desviación estándar de intensidad;
# - porcentaje de saturación;
# - porcentaje de píxeles en cero;
# - porcentaje de profundidad válida;
# - profundidad media válida;
# - desviación estándar de profundidad.
#
# Este análisis permite valorar si la calidad visual de la imagen se relaciona con la disponibilidad o estabilidad de la profundidad estimada.

# %%
# Integración de métricas RGB y profundidad por secuencia e índice aproximado de frame.

rgb_corr_cols = [
    "sequence",
    "frame_index",
    "mean_intensity",
    "std_intensity",
    "zero_pct",
    "saturated_255_pct"
]

depth_corr_cols = [
    "sequence",
    "frame_index",
    "valid_pct",
    "invalid_pct",
    "depth_mean_valid",
    "depth_median_valid",
    "depth_std_valid"
]

rgb_for_corr = rgb_temporal_df[rgb_corr_cols].copy() if not rgb_temporal_df.empty else pd.DataFrame()
depth_for_corr = depth_temporal_df[depth_corr_cols].copy() if not depth_temporal_df.empty else pd.DataFrame()

hamlyn_corr_base = pd.merge(
    rgb_for_corr,
    depth_for_corr,
    on=["sequence", "frame_index"],
    how="inner"
)

print("Registros integrados para correlación:", len(hamlyn_corr_base))
display(hamlyn_corr_base.head())

hamlyn_corr_base.to_csv(
    OUTPUT_DIR / "tables" / "hamlyn_correlation_base.csv",
    index=False
)
# Out:
# Registros integrados para correlación: 38320
#       sequence  frame_index  mean_intensity  std_intensity  zero_pct  \
# 0  rectified01            0      100.135750      47.241112  4.580946
# 1  rectified01            1      100.788177      47.441814  4.586480
# 2  rectified01            2      100.716316      47.348232  4.583442
# 3  rectified01            3      100.190529      47.235149  4.597656
# 4  rectified01            4      100.849876      47.453373  4.593207
#
#    saturated_255_pct  valid_pct  invalid_pct  depth_mean_valid  \
# 0           0.003798  82.782552    17.217448         81.343445
# 1           0.003038  83.411784    16.588216         81.384384
# 2           0.003147  84.456055    15.543945         81.081093
# 3           0.002930  84.921875    15.078125         81.013077
# 4           0.004123  84.936198    15.063802         81.159508
#
#    depth_median_valid  depth_std_valid
# 0                83.0        10.380792
# 1                83.0        10.312531
# 2                82.0        10.092916
# 3                82.0        10.223222
# 4                83.0        10.230902

# %%
# Matriz de correlación exploratoria.

corr_variables = [
    "mean_intensity",
    "std_intensity",
    "zero_pct",
    "saturated_255_pct",
    "valid_pct",
    "invalid_pct",
    "depth_mean_valid",
    "depth_median_valid",
    "depth_std_valid"
]

available_corr_variables = [col for col in corr_variables if col in hamlyn_corr_base.columns]

if len(available_corr_variables) >= 2:
    hamlyn_corr_matrix = hamlyn_corr_base[available_corr_variables].corr()
    
    display(hamlyn_corr_matrix.round(3))
    
    hamlyn_corr_matrix.to_csv(
        OUTPUT_DIR / "tables" / "hamlyn_correlation_matrix.csv"
    )
else:
    hamlyn_corr_matrix = pd.DataFrame()
    print("No hay suficientes variables para calcular correlación.")
# Out:
#                     mean_intensity  std_intensity  zero_pct  \
# mean_intensity               1.000          0.262    -0.225
# std_intensity                0.262          1.000     0.022
# zero_pct                    -0.225          0.022     1.000
# saturated_255_pct           -0.081          0.631     0.429
# valid_pct                    0.536          0.062    -0.062
# invalid_pct                 -0.536         -0.062     0.062
# depth_mean_valid             0.407         -0.344    -0.127
# depth_median_valid           0.411         -0.336    -0.121
# depth_std_valid              0.112         -0.385    -0.091
#
#                     saturated_255_pct  valid_pct  invalid_pct  \
# mean_intensity                 -0.081      0.536       -0.536
# std_intensity                   0.631      0.062       -0.062
# zero_pct                        0.429     -0.062        0.062
# saturated_255_pct               1.000      0.102       -0.102
# valid_pct                       0.102      1.000       -1.000
# invalid_pct                    -0.102     -1.000        1.000
# depth_mean_valid               -0.288      0.509       -0.509
# depth_median_valid             -0.256      0.541       -0.541
# depth_std_valid                -0.368      0.126       -0.126
#
#                     depth_mean_valid  depth_median_valid  depth_std_valid
# mean_intensity                 0.407               0.411            0.112
# std_intensity                 -0.344              -0.336           -0.385
# zero_pct                      -0.127              -0.121           -0.091
# saturated_255_pct             -0.288              -0.256           -0.368
# valid_pct                      0.509               0.541            0.126
# invalid_pct                   -0.509              -0.541           -0.126
# depth_mean_valid               1.000               0.991            0.681
# depth_median_valid             0.991               1.000            0.619
# depth_std_valid                0.681               0.619            1.000

# %%
# Visualización de matriz de correlación.

if not hamlyn_corr_matrix.empty:
    plt.figure(figsize=(10, 8))
    im = plt.imshow(hamlyn_corr_matrix, aspect="auto")
    plt.colorbar(im, fraction=0.046, pad=0.04)
    
    plt.xticks(
        ticks=np.arange(len(hamlyn_corr_matrix.columns)),
        labels=hamlyn_corr_matrix.columns,
        rotation=45,
        ha="right"
    )
    plt.yticks(
        ticks=np.arange(len(hamlyn_corr_matrix.index)),
        labels=hamlyn_corr_matrix.index
    )
    
    plt.title("Matriz de correlación exploratoria HAMLYN")
    
    # Anotar valores
    for i in range(len(hamlyn_corr_matrix.index)):
        for j in range(len(hamlyn_corr_matrix.columns)):
            value = hamlyn_corr_matrix.iloc[i, j]
            plt.text(j, i, f"{value:.2f}", ha="center", va="center")
    
    plt.tight_layout()
    
    out_path = OUTPUT_DIR / "figures" / "hamlyn_correlation_matrix.png"
    plt.savefig(out_path, dpi=160, bbox_inches="tight")
    plt.show()
    
    print("Figura guardada:", out_path)
# Out:
# Figura guardada: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn/figures/hamlyn_correlation_matrix.png

# %%
# Correlaciones más relevantes respecto a profundidad válida y profundidad media.

if not hamlyn_corr_matrix.empty:
    key_targets = ["valid_pct", "depth_mean_valid"]
    
    relevant_corrs = []
    for target in key_targets:
        if target in hamlyn_corr_matrix.columns:
            series = hamlyn_corr_matrix[target].drop(labels=[target], errors="ignore")
            series = series.sort_values(key=lambda x: x.abs(), ascending=False)
            
            for variable, corr_value in series.items():
                relevant_corrs.append({
                    "target": target,
                    "variable": variable,
                    "correlation": corr_value,
                    "abs_correlation": abs(corr_value)
                })
    
    relevant_corrs_df = pd.DataFrame(relevant_corrs)
    
    if not relevant_corrs_df.empty:
        relevant_corrs_df["correlation"] = relevant_corrs_df["correlation"].round(4)
        relevant_corrs_df["abs_correlation"] = relevant_corrs_df["abs_correlation"].round(4)
        display(relevant_corrs_df)
        
        relevant_corrs_df.to_csv(
            OUTPUT_DIR / "tables" / "hamlyn_relevant_correlations.csv",
            index=False
        )
else:
    relevant_corrs_df = pd.DataFrame()
# Out:
#               target            variable  correlation  abs_correlation
# 0          valid_pct         invalid_pct      -1.0000           1.0000
# 1          valid_pct  depth_median_valid       0.5408           0.5408
# 2          valid_pct      mean_intensity       0.5363           0.5363
# 3          valid_pct    depth_mean_valid       0.5090           0.5090
# 4          valid_pct     depth_std_valid       0.1258           0.1258
# 5          valid_pct   saturated_255_pct       0.1022           0.1022
# 6          valid_pct            zero_pct      -0.0624           0.0624
# 7          valid_pct       std_intensity       0.0620           0.0620
# 8   depth_mean_valid  depth_median_valid       0.9913           0.9913
# 9   depth_mean_valid     depth_std_valid       0.6814           0.6814
# 10  depth_mean_valid         invalid_pct      -0.5090           0.5090
# 11  depth_mean_valid           valid_pct       0.5090           0.5090
# 12  depth_mean_valid      mean_intensity       0.4071           0.4071
# 13  depth_mean_valid       std_intensity      -0.3443           0.3443
# 14  depth_mean_valid   saturated_255_pct      -0.2879           0.2879
# 15  depth_mean_valid            zero_pct      -0.1266           0.1266

# %% [markdown]
# ## 17. Respuesta sintética a las preguntas de la rúbrica
#
# La siguiente tabla organiza los resultados del EDA de HAMLYN en función de las preguntas guía de la rúbrica. Esta tabla puede incorporarse directamente al reporte o usarse como base para la redacción formal.

# %%
rubric_rows = [
    {
        "pregunta": "¿Hay valores faltantes en el conjunto de datos? ¿Se pueden identificar patrones de ausencia?",
        "respuesta_hamlyn": "Sí. En HAMLYN los valores faltantes se manifiestan principalmente como píxeles de profundidad inválidos o fuera del rango definido como válido. El patrón de ausencia varía por secuencia y puede asociarse con oclusiones, baja textura, reflejos especulares o fallas de correspondencia estéreo.",
        "evidencia": "hamlyn_depth_summary_by_sequence.csv; figuras de máscara válida por secuencia."
    },
    {
        "pregunta": "¿Cuáles son las estadísticas resumidas del conjunto de datos?",
        "respuesta_hamlyn": "Se calcularon estadísticas por secuencia para imágenes RGB y mapas de profundidad: número de archivos, resolución, intensidad media, saturación, profundidad media, mediana, desviación estándar y porcentaje de píxeles válidos.",
        "evidencia": "hamlyn_rgb_summary_by_sequence.csv; hamlyn_depth_summary_by_sequence.csv."
    },
    {
        "pregunta": "¿Hay valores atípicos en el conjunto de datos?",
        "respuesta_hamlyn": "Sí. Se identifican posibles valores atípicos en profundidad por bajo porcentaje de píxeles válidos y en RGB por saturación o exceso de valores cero.",
        "evidencia": "hamlyn_depth_possible_outliers.csv; hamlyn_rgb_possible_outliers.csv."
    },
    {
        "pregunta": "¿Cuál es la cardinalidad de las variables categóricas?",
        "respuesta_hamlyn": "La cardinalidad categórica principal corresponde a cinco secuencias, dos modalidades funcionales principales —RGB y profundidad—, dos extensiones principales —JPG y PNG— y dos resoluciones dominantes.",
        "evidencia": "hamlyn_filetype_summary.csv; hamlyn_resolution_summary.csv."
    },
    {
        "pregunta": "¿Existen distribuciones sesgadas en el conjunto de datos? ¿Necesitamos aplicar alguna transformación no lineal?",
        "respuesta_hamlyn": "Sí. Los histogramas de profundidad muestran concentraciones y dispersión desigual entre secuencias. Para visualización se recomienda normalización por percentiles; para modelado puede evaluarse escalamiento robusto o filtrado de rangos inválidos.",
        "evidencia": "Figuras de control visual por secuencia; hamlyn_depth_summary_by_sequence.csv."
    },
    {
        "pregunta": "¿Se identifican tendencias temporales?",
        "respuesta_hamlyn": "Sí, se incorporó un análisis temporal aproximado por orden de frame para observar cambios en intensidad promedio, porcentaje de profundidad válida y profundidad media a lo largo de cada secuencia.",
        "evidencia": "hamlyn_temporal_summary_by_sequence.csv; temporal_mean_rgb_intensity_by_sequence.png; temporal_valid_depth_pct_by_sequence.png; temporal_mean_depth_by_sequence.png."
    },
    {
        "pregunta": "¿Hay correlación entre las variables dependientes e independientes?",
        "respuesta_hamlyn": "Se calculó una correlación exploratoria entre variables visuales y geométricas. Dado que HAMLYN no es un dataset tabular supervisado clásico, esta correlación se interpreta como relación entre calidad visual y calidad de profundidad, no como causalidad predictiva definitiva.",
        "evidencia": "hamlyn_correlation_matrix.csv; hamlyn_correlation_matrix.png; hamlyn_relevant_correlations.csv."
    },
    {
        "pregunta": "¿Cómo se distribuyen los datos en función de diferentes categorías?",
        "respuesta_hamlyn": "Los datos se distribuyen por secuencia, tipo de archivo, modalidad, resolución y métricas de validez. rectified08 concentra la mayor volumetría, mientras que las demás secuencias tienen menor cantidad de pares imagen-profundidad.",
        "evidencia": "hamlyn_filetype_summary.csv; hamlyn_resolution_summary.csv."
    },
    {
        "pregunta": "¿Se deberían normalizar las imágenes para visualizarlas mejor?",
        "respuesta_hamlyn": "Sí. Las diferencias de intensidad media y saturación entre secuencias justifican normalización para visualización y estandarización antes del entrenamiento de modelos.",
        "evidencia": "hamlyn_rgb_summary_by_sequence.csv; mean_rgb_intensity_by_sequence.png."
    },
    {
        "pregunta": "¿Hay desequilibrio en las clases de la variable objetivo?",
        "respuesta_hamlyn": "No aplica en sentido clásico porque HAMLYN no es una base de clasificación por clases. La variable objetivo funcional es continua: profundidad por píxel. Sin embargo, sí existe desequilibrio en la cobertura de profundidad válida entre secuencias.",
        "evidencia": "hamlyn_depth_summary_by_sequence.csv; mean_valid_pct_by_sequence.png."
    }
]

hamlyn_rubric_response = pd.DataFrame(rubric_rows)
display(hamlyn_rubric_response)

hamlyn_rubric_response.to_csv(
    OUTPUT_DIR / "tables" / "hamlyn_rubric_response.csv",
    index=False
)

print("Tabla de respuesta a rúbrica exportada:", OUTPUT_DIR / "tables" / "hamlyn_rubric_response.csv")
# Out:
#                                                                                                           pregunta  \
# 0                     ¿Hay valores faltantes en el conjunto de datos? ¿Se pueden identificar patrones de ausencia?
# 1                                                    ¿Cuáles son las estadísticas resumidas del conjunto de datos?
# 2                                                                   ¿Hay valores atípicos en el conjunto de datos?
# 3                                                           ¿Cuál es la cardinalidad de las variables categóricas?
# 4  ¿Existen distribuciones sesgadas en el conjunto de datos? ¿Necesitamos aplicar alguna transformación no lineal?
# 5                                                                           ¿Se identifican tendencias temporales?
# 6                                              ¿Hay correlación entre las variables dependientes e independientes?
# 7                                              ¿Cómo se distribuyen los datos en función de diferentes categorías?
# 8                                                   ¿Se deberían normalizar las imágenes para visualizarlas mejor?
# 9                                                        ¿Hay desequilibrio en las clases de la variable objetivo?
#
#                                                                                                                               respuesta_hamlyn  \
# 0  Sí. En HAMLYN los valores faltantes se manifiestan principalmente como píxeles de profundidad inválidos o fuera del rango definido como ...
# 1  Se calcularon estadísticas por secuencia para imágenes RGB y mapas de profundidad: número de archivos, resolución, intensidad media, sat...
# 2  Sí. Se identifican posibles valores atípicos en profundidad por bajo porcentaje de píxeles válidos y en RGB por saturación o exceso de v...
# 3  La cardinalidad categórica principal corresponde a cinco secuencias, dos modalidades funcionales principales —RGB y profundidad—, dos ex...
# 4  Sí. Los histogramas de profundidad muestran concentraciones y dispersión desigual entre secuencias. Para visualización se recomienda nor...
# 5  Sí, se incorporó un análisis temporal aproximado por orden de frame para observar cambios en intensidad promedio, porcentaje de profundi...
# 6  Se calculó una correlación exploratoria entre variables visuales y geométricas. Dado que HAMLYN no es un dataset tabular supervisado clá...
# 7  Los datos se distribuyen por secuencia, tipo de archivo, modalidad, resolución y métricas de validez. rectified08 concentra la mayor vol...
# 8  Sí. Las diferencias de intensidad media y saturación entre secuencias justifican normalización para visualización y estandarización ante...
# 9  No aplica en sentido clásico porque HAMLYN no es una base de clasificación por clases. La variable objetivo funcional es continua: profu...
#
#                                                                                                                                      evidencia
# 0                                                               hamlyn_depth_summary_by_sequence.csv; figuras de máscara válida por secuencia.
# 1                                                                    hamlyn_rgb_summary_by_sequence.csv; hamlyn_depth_summary_by_sequence.csv.
# 2                                                                        hamlyn_depth_possible_outliers.csv; hamlyn_rgb_possible_outliers.csv.
# 3                                                                                  hamlyn_filetype_summary.csv; hamlyn_resolution_summary.csv.
# 4                                                               Figuras de control visual por secuencia; hamlyn_depth_summary_by_sequence.csv.
# 5  hamlyn_temporal_summary_by_sequence.csv; temporal_mean_rgb_intensity_by_sequence.png; temporal_valid_depth_pct_by_sequence.png; temporal...
# 6                                              hamlyn_correlation_matrix.csv; hamlyn_correlation_matrix.png; hamlyn_relevant_correlations.csv.
# 7                                                                                  hamlyn_filetype_summary.csv; hamlyn_resolution_summary.csv.
# 8                                                                      hamlyn_rgb_summary_by_sequence.csv; mean_rgb_intensity_by_sequence.png.
# 9                                                                        hamlyn_depth_summary_by_sequence.csv; mean_valid_pct_by_sequence.png.
# Tabla de respuesta a rúbrica exportada: /Users/eldamorales/Documents/Maestría en IA/Proyecto Integrador/proyecto_integrador_52/outputs/hamlyn/tables/hamlyn_rubric_response.csv

# %% [markdown]
# ## 18. Cierre metodológico
#
# Este notebook constituye la base del análisis exploratorio de HAMLYN. Su propósito no es entrenar todavía un modelo predictivo, sino dejar listo el diagnóstico de datos necesario para justificar decisiones posteriores de preprocesamiento, normalización, filtrado y partición de entrenamiento.

# %% [markdown]
# ---
#
# ## Agradecimientos
#
# El Equipo 52 agradece la orientacion y asesoria tecnica del **Dr. Gilberto Ochoa Ruiz** y del **Dr. Ricardo Espinosa Loera** (Universite de Lorraine), cuyas contribuciones al campo de la vision por computadora y el procesamiento de imagenes medicas enriquecieron el diseno metodologico de este proyecto.
